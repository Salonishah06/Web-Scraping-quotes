# %%
#Import libraries
from bs4 import BeautifulSoup
import requests
import time
import datetime
import smtplib
import urllib.request

# %%
authors=[]
quotes=[]

# %%
URL= "https://www.goodreads.com/quotes/tag?id=data+science&page=1"

webpage=requests.get(URL)

soup=BeautifulSoup(webpage.content,"html.parser")
quoteText=soup.find_all('div',attrs={'class','quoteText'})

# %%
quoteText

# %%
for i in quoteText :
  quote=i.text.strip().split('/n')[0]
  print(quote)
  author=i.find('span', attrs={'class':'authorOrTitle'}).text.strip()
  print(author)

# %%
def scrape_website(page_number):
   page_num= str(page_number) 
   URL= "https://www.goodreads.com/quotes/tag?id=machine+learning&utf=8&page="+page_num
   webpage=requests.get(URL)
   soup=BeautifulSoup(webpage.content,"html.parser")
   quoteText=soup.find_all('div',attrs={'class','quoteText'})


for i in quoteText :
  quote=i.text.strip().split('/n')[0]
  author=i.find('span', attrs={'class':'authorOrTitle'}).text.strip()
  quotes.append(quote)
  authors.append(author)

# %%
scrape_website(1)

# %%
n=10
for num in range(0,n):
  scrape_website(num)

# %%
authors

# %%
quote
# Out:
# '“The cleaning of data can remove its queerness: paper surveys where respondents score out the response options ‘female’ and ‘male’ and write their own answer, interview recordings were participants flip the focus and ask questions of the researcher, census returns where LGBTQ couples identify themselves as ‘married’ even when governments do not recognize same sex marriage. These examples demonstrate how collection methods can fail to restrict how participants share data about their lives and experiences. … cleaning, which involves the removal of data that breaks established rules”\n    ―\n  \n    Kevin Guyan,\n  \n\nQueer Data: Using Gender, Sex and Sexuality Data for Action\n\n\n//<![CDATA[\n      var newTip = new Tip($(\'quote_book_link_57917062\'), "\\n\\n  <h2><a class=\\"readable bookTitle\\" href=\\"https://www.goodreads.com/book/show/57917062-queer-data?from_choice=false&amp;from_home_module=false\\">Queer Data: Using Gender, Sex and Sexuality Data for Action<\\/a><\\/h2>\\n\
# ...

# %%
import csv

header = ['Quotes','Authors']
data = [quote, author]

with open('InspirationalQuotes.csv','w', newline='', encoding='UTF8') as f:
  writer = csv.writer(f)
  writer.writerow(header)
  writer.writerow(data)

for i in range(len(quotes)):
  data=[quotes[i], authors[i]]

  with open('/content/InspirationalQuotes.csv','a', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)
